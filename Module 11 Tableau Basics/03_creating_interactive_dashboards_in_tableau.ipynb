# %% [markdown]
# <p style="display: flex; align-items: center;">
#     <img src="https://www.tableau.com/themes/custom/tableau_www/logo.v2.svg" alt="Seaborn Logo" width="190" style="margin-right: 10px;">
#     <span style="font-size: 32px; font-weight: bold;">📍 Creating Interactive Dashboards in Tableau</span>
# </p>

# %% [markdown]
# ## Introduction
# In this lesson, we'll explore how to create **interactive dashboards** in Tableau. Dashboards allow users to combine multiple visualizations, apply filters, and interact dynamically with the data to uncover insights.
#
# We'll demonstrate the key components of an interactive dashboard using Tableau's **Superstore Sales** dataset. You can download this dataset from Tableau's official sample data repository: [Superstore Sales Dataset](https://public.tableau.com/app/sample-data/sample_-_superstore.xls).

# %% [markdown]
# ## Step 1: Load the Dataset
# 1. Open Tableau and navigate to **Connect > Microsoft Excel**.
#
# <div style="text-align: center;">
#     <img src="images/connect_to_excel.png" alt="Connect > Microsoft Excel" width="150">
# </div>
#
# 2. Select the **Superstore Sales** dataset file.
#
# <div style="text-align: center;">
#     <img src="images/select_superstore_sales.png" alt="Select Superstore Sales" width="850">
# </div>
#
# 3. Drag the `Orders` sheet to the data pane.
#
# <div style="text-align: center;">
#     <img src="images/drag_orders.png" alt="Drag Orders" width="750">
# </div>
#
# Once the data is loaded, move to **Sheet 1** to start creating visualizations.
#
# <div style="text-align: center;">
#     <img src="images/move_sheet_1.png" alt="Move to Sheet 1" width="750">
# </div>

# %% [markdown]
# ## Step 2: Create Individual Visualizations
# A dashboard consists of multiple visualizations. We'll create three key visualizations for our interactive dashboard:
#
# ### 1. Sales by Region (Map Visualization)
# 1. Drag `State` to the **Columns** shelf and `Sales` to the **Rows** shelf.
#
# <div style="text-align: center;">
#     <img src="images/sales_by_region_1.png" alt="Sales By Region 1" width="750">
# </div>
#
# 2. Change the **Chart Type** by selecting **Map** from the **Show Me** panel.
#
# <div style="text-align: center;">
#     <img src="images/map_type.png" alt="Map Type" width="750">
# </div>
#
# 3. Rename the sheet to `Sales by Region`.
#
# <div style="text-align: center;">
#     <img src="images/sales_by_region.png" alt="Map Type" width="750">
# </div>

# %% [markdown]
# ### 2. Sales Over Time (Line Chart)
# 1. Open a new sheet and rename it `Sales Over Time`.
#
# <div style="text-align: center;">
#     <img src="images/sales_over_time.png" alt="Sales Over Time" width="750">
# </div>
#
# 2. Drag `Order Date` to the **Columns** shelf and `Sales` to the **Rows** shelf.
#
# <div style="text-align: center;">
#     <img src="images/sales_over_time_2.png" alt="Sales Over Time Columns and Rows" width="750">
# </div>
#
# 3. Change `Order Date` to `Continuous Month` to show a time series.
#
# <div style="text-align: center;">
#     <img src="images/sales_over_time_3.png" alt="Sales Over Time - Time Series" width="750">
# </div>
#
# 4. Format the chart by adding **Trend Lines** (Analytics Pane > Trend Line).
#
# <div style="text-align: center;">
#     <img src="images/sales_over_time_4.png" alt="Sales Over Time - Trend Line" width="750">
# </div>

# %% [markdown]
# ### 3. Sales by Category (Bar Chart)
# 1. Create a new sheet and rename it `Sales by Category`.
#
# <div style="text-align: center;">
#     <img src="images/sales_by_category_1.png" alt="Sales by Category" width="750">
# </div>
#
# 2. Drag `Category` to the **Columns** shelf and `Sales` to the **Rows** shelf.
#
# <div style="text-align: center;">
#     <img src="images/sales_by_category_2.png" alt="Sales by Category Columns and Rows" width="750">
# </div>
#
# 3. Add `Sub-Category` to **Color** for better distinction.
#
# <div style="text-align: center;">
#     <img src="images/sales_by_category_3.png" alt="Sales by Category - Sub-Category" width="750">
# </div>
#
# 4. Sort the bars in descending order.
#
# <div style="text-align: center;">
#     <img src="images/sales_by_category_4.png" alt="Sales by Category - Descending" width="750">
# </div>

# %% [markdown]
# ## Step 3: Build the Dashboard
# 1. Navigate to **Dashboard > New Dashboard**.
#
# <div style="text-align: center;">
#     <img src="images/build_dashboard_1.png" alt="New Dashboard" width="750">
# </div>
#
# 2. Drag the three visualizations (`Sales by Region`, `Sales Over Time`, `Sales by Category`) into the dashboard.
#
# <div style="text-align: center;">
#     <img src="images/build_dashboard_2.png" alt="Drag Visualizations" width="750">
# </div>
#
# 3. Arrange them using **Tiled Layout** to ensure a clean structure.
#
# <div style="text-align: center;">
#     <img src="images/build_dashboard_3.png" alt="Dashboard Layout" width="750">
# </div>
#
# 4. Add **Titles** and **Text** elements to describe the dashboard's purpose.
#
# <div style="text-align: center;">
#     <img src="images/build_dashboard_4.png" alt="Dashboard Customization" width="750">
# </div>

# %% [markdown]
# ## Step 4: Add Interactivity
# ### 1. Filters
# 1. Select the `Sales by Region` map.
#
# <div style="text-align: center;">
#     <img src="images/filters1.png" alt="Filters 1" width="650">
# </div>
#
# 2. Click **Use as Filter** (on the top-right of the sheet container).
#
# <div style="text-align: center;">
#     <img src="images/filters2.png" alt="Filters 2" width="650">
# </div>
#
# 3. Click on any region in the map; it should filter the other two charts dynamically.
#
# <div style="text-align: center;">
#     <img src="images/filters3.png" alt="Filters 3" width="650">
# </div>

# %% [markdown]
# ### 2. Highlight
# 1. Go to **Dashboard > Highlight**.
#
# <div style="text-align: center;">
#     <img src="images/highlight1.png" alt="Highlight 1" width="650">
# </div>
#
# 2. Choose any category to highlight in all highlight all visualizations.
#
# <div style="text-align: center;">
#     <img src="images/highlight2.png" alt="Highlight 2" width="650">
# </div>
#
# <br>
# <br>
#
# <div style="text-align: center;">
#     <img src="images/highlight3.png" alt="Highlight 3" width="650">
# </div>

# %% [markdown]
# ## Step 5: Customize the Dashboard
# ### 1. Layout and Design
# - Use **Containers** for better spacing and organization.
#
# - Set **Background Colors** and Borders for distinction.
#
# - Adjust **Titles and Tooltips** for clarity.
#
# ### 2. Color Schemes
# - Choose a consistent color palette under **Format > Workbook Theme**.
#
# - Use contrasting colors for better readability.
#
# ### 3. Final Touches
# - Add a **Legend** to explain color coding.
#
# - Include **Dashboard Instructions** using a Text Box.
#
# - Test the interactivity by selecting different regions, adjusting filters, and using the parameter control.
#
# ## Summary
# ### Key Takeaways
# - **Dashboards** combine multiple visualizations into an interactive view.
#
# - **Filters and parameters** enhance user interactivity by allowing real-time adjustments.
#
# - **Dashboard Actions** (Filters, Highlights) enable dynamic interactions across charts.
#
# - **Layout and design** considerations ensure a clean and engaging user experience.
#
# ### Next Lesson Preview
# In the next module, we'll transition from Tableau to **Shiny**, where we'll explore how to build more dynamic web applications for interactive data visualization.
