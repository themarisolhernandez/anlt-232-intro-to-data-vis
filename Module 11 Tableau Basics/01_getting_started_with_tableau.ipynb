# %% [markdown]
# <p style="display: flex; align-items: center;">
#     <img src="https://www.tableau.com/themes/custom/tableau_www/logo.v2.svg" alt="Seaborn Logo" width="190" style="margin-right: 10px;">
#     <span style="font-size: 32px; font-weight: bold;">📍 Getting Started with Tableau</span>
# </p>

# %% [markdown]
# ## What is Tableau?
# [**Tableau**](https://www.tableau.com/) is a leading data visualization and business intelligence tool that enables users to analyze data and generate insights through interactive dashboards and reports. Unlike coding-based tools such as Dash, Tableau provides a **drag-and-drop interface** that allows users to build visualizations with minimal programming knowledge.
#
# ![Intro to Tableau](images/intro_to_tableau.png)
#
# **Tableau** is widely used in industries such as finance, healthcare, marketing, and operations due to its ability to quickly process large datasets and create compelling data stories. Organizations use Tableau for tasks such as:
#
# - **Sales and revenue analysis** – Tracking company performance and trends.
#
# - **Customer segmentation** – Identifying key customer groups based on behaviors.
#
# - **Supply chain optimization** – Monitoring inventory and logistics in real time
#
# ### Key Benefits of Tableau
# 1. **User-friendly Interface**: Drag-and-drop functionality makes it accessible to non-programmers.
#
# 2. **High-Speed Data Processing** – Can handle large datasets efficiently.
#
# 3. **Data Connectivity** – Supports connection to various data sources such as Excel, SQL databases, Google Sheets, and cloud-based data warehouses.
#
# 4. **Interactive Dashboards** – Allows for filtering, drill-downs, and dynamic visualizations.
#
# 5. **Enterprise Scalability** – Can be deployed at an organizational level using Tableau Server or Tableau Cloud.
#
# ### Tableau Product Offerings
# There are multiple versions of Tableau to cater to various user needs:
#
# | Tableau Product | Description | Best For |
# |----------|----------|----------|
# | **Tableau Public** | 	Free version for creating and sharing visualizations online | Beginners and students |
# | **Tableau Desktop** | Paid version with full functionality and the ability to save work locally | Analysts and professionals |
# | **Tableau Server** | Enterprise solution for hosting and sharing dashboards within an organization | Large businesses |
# | **Tableau Cloud** | Cloud-hosted version of Tableau Server for remote access and collaboration | Teams working across different locations |
#
# 💡 *Note: For this course, we'll use Tableau Public, a free version suitable for learning and sharing visualizations.*

# %% [markdown]
# ## What is Tableau Public?
# **Tableau Public** is a free platform for creating, publishing, and sharing interactive visualizations with a global audience. It’s an excellent way to learn Tableau, showcase your work, and explore dashboards created by others—all without needing a paid license.
#
# However, keep in mind that everything shared on Tableau Public is accessible to everyone. Make sure any data you publish is intended for <u>public consumption</u>! If you need to work with private data, consider [Tableau’s other offerings](https://www.tableau.com/products).
#
# ### Getting Started with Tableau Public
# 1. **Create a Tableau Public Account**: You can sign-up for **Tableau Public** by clicking this [link](https://id.tableau.com/register?clientId=wcS7HwY98qdfgBREHT7Xoln7ipc75U0a) or by navigating to the **Sign In** at the top of any page on https://public.tableau.com/app/discover.
#
# <div style="text-align: center;">
#     <img src="images/create_tableau_acct.png" alt="Create Tableau Account" width="400">
# </div>
#
# 💡 *Signing up for a **Tableau Public account** is always free and takes less than 60 seconds!*
#
# 2. **Choose Your Environment:** There are two ways to create visualizations in Tableau Public: <div style="text-align: center;">
#     <img src="images/choose_your_env.png" alt="Create Tableau Account" width="400">
# </div>
#
#     A. **Web Authoring (In-Browser)** – No installation required! You can start building visualizations directly in your browser at Tableau Public. Just sign in and click **"Create" > "Web Authoring"** to begin.
#
#     B. **Tableau Desktop Public Edition** – A more feature-rich option that requires installation. You can download and install it for free if you prefer working from your desktop.
#
# 3. **(Optional) Install Tableau Desktop Public Edition:** If you'd like to use **Tableau Desktop Public Edition**, follow these steps:
#
#     - **Step 1:** Download the installer from the [official Tableau Public site](https://www.tableau.com/products/public/download).
#
#     - **Step 2:** Open the downloaded file and follow the on-screen installation instructions. No license key is required!
#
#     - **Step 3:** Once installed, launch Tableau and click **"Sign In"** at the top right to log in with your **Tableau Public** account.
#
# 💡 *Both environments offer nearly identical interfaces, so feel free to choose the one that works best for you!*

# %% [markdown]
# ## Exploring the Tableau Interface
# Once installed, launch **Tableau Public** to familiarize yourself with its interface.
#
# ### Key Components of the Tableau Interface
#
# | Component | Description |
# |----------|----------|
# | **Start Page** | Provides access to recent workbooks and data connection options. |
# | **Data Pane** | Displays connected data fields, categorized as **Dimensions** (categorical) and **Measures** (numerical). |
# | **Sheets (Worksheets)** | Individual canvases where visualizations are created. |
# | **Marks Card** | Controls the appearance of visual elements (color, size, labels, tooltips). |
# | **Filters & Pages Shelves** | Allow filtering and creating animated views over time. |
# | **Show Me Panel** | Recommends visualization types based on selected data fields. |
# | **Dashboard & Story Tabs** | Combine multiple visualizations into interactive dashboards or guided narratives. |
#
# <div style="text-align: center;">
#     <img src="images/tableau_interface.png" alt="Tableau Interface" width="850">
# </div>
#
# #### Navigating the Interface
# - The **Data Pane** is where you drag fields to create visualizations.
#
# - The **Rows and Columns shelves** determine how data is displayed.
#
# - The **Marks Card** helps customize chart elements.
#
# - The **Show Me panel** suggests different chart types.
#
# 💡 *Tip: Spend a few minutes exploring the interface before moving forward.*

# %% [markdown]
# ## Connecting to Data
# ### Supported Data Sources
# Tableau can connect to various data formats, including:
#
# - **Excel (XLSX, CSV, Google Sheets)**
#
# - **Relational Databases (SQL Server, MySQL, PostgreSQL)**
#
# - **Cloud Services (Amazon Redshift, Google BigQuery, Snowflake)**
#
# For this lesson, we’ll use a **sample data source**.
#
# ### Connect to Data
# 1. On the data pane, click **“Connect to Data”**.
#
# <div style="text-align: center;">
#     <img src="images/connect_to_data.png" alt="Connect to Data" width="150">
# </div>
#
# 2. Select any data source. For demo purposes, I'll connect to a **sample data source**, `Sample - Superstore`. Tableau provides a number of [sample data sets](https://public.tableau.com/app/learn/sample-data?_gl=1*bn1crj*_ga*MjAyMjQ2NTkzOC4xNzQzMzQ3NzE0*_ga_8YLN0SNXVS*MTc0MzM0NzcxMy4xLjAuMTc0MzM0NzcxMy4wLjAuMA..).
#
# <div style="text-align: center;">
#     <img src="images/data_source.png" alt="Data Source" width="600">
# </div>
#
# 3. Tableau provides a preview of the data fields and types in the **data pane**.
#
# <div style="text-align: center;">
#     <img src="images/data_pane.png" alt="Data Pane" width="150">
# </div>

# %% [markdown]
# ## Understanding Dimensions vs. Measures
# Tableau automatically classifies data fields into two categories:
#
# - <span style="color: blue;">**Dimensions (Blue fields)**</span> → Categorical data that defines groups (e.g., `Customer Name`, `City`, `Product Category`).
#
# - <span style="color: green;">**Measures (Green fields)**</span> → Numerical data that can be aggregated (e.g., `Sales`, `Profit,`, `Quantity`).
#
# 💡 *You can manually adjust a field’s classification by dragging it between **Dimensions** and **Measures**.*
#
# <div style="text-align: center;">
#     <img src="images/dimensions_vs_measures.png" alt="Dimensions vs Measures" width="250">
# </div>

# %% [markdown]
# ## Creating Your First Visualization
# We'll build a simple **bar chart** to analyze sales by category.
#
# ### Steps to Create a Bar Chart
# 1. Open a new worksheet if you haven't already.
#
# 2. Drag `Category` from the **Data Pane** onto the **Columns** shelf. `Category` falls under the hierarchical of `Product` so you may need to expand the drop down.
#
# <div style="text-align: center;">
#     <img src="images/category_column.png" alt="Category Column" width="600">
# </div>
#
# 3. Drag `Sales` onto the **Rows** shelf.
#
# <div style="text-align: center;">
#     <img src="images/sales_row.png" alt="Sales Row" width="600">
# </div>
#
# 4. Tableau automatically generates a **bar chart**.
#
# <div style="text-align: center;">
#     <img src="images/bar_chart.png" alt="Bar Chart" width="600">
# </div>
#
# #### Customizing the Chart:
# 1. Drag `Profit` to **Color (Marks Card)** to visually differentiate profitability.
#
# <div style="text-align: center;">
#     <img src="images/profit_color.png" alt="Profit Color" width="600">
# </div>
#
# 2. Click on the **Sort** icon to arrange bars in descending order.
#
# <div style="text-align: center;">
#     <img src="images/sort_bars.png" alt="Sort Bars" width="600">
# </div>
#
# 3. Add labels by dragging `Sales` to the **Label** section of the **Marks Card**.
#
# <div style="text-align: center;">
#     <img src="images/labels.png" alt="Labels" width="600">
# </div>
#
# 💡 *Experiment with different options to see how the visualization changes.*

# %% [markdown]
# ## Choosing the Right Chart Type
# Tableau provides various visualization options, each suited for different types of analysis.
#
# | Chart Type | Best For | Example Use Cases |
# |----------|----------|----------|
# | **Bar Chart** | Comparing categories | Sales by product category |
# | **Line Chart** | Showing trends over time | Revenue growth over months |
# | **Scatter Plot** | 	Identifying relationships | Profit vs. sales per region |
# | **Pie Chart** | 	Showing proportions | Market share by brand |
# | **Map** | Geospatial data | Sales by country |
#
# 💡 *To switch between chart types, use the **Show Me** panel.*
#
# <div style="text-align: center;">
#     <img src="images/show_me.png" alt="Show Me" width="150">
# </div>

# %% [markdown]
# ## Saving and Publishing Your Work
# Tableau Public requires users to publish their work online, as local saving is not supported.
#
# ### Steps to Save and Publish:
# 1. Click **File > Save to Tableau Public As…**
#
# 2. Log in to your **Tableau Public account**.
#
# 3. Enter a **title** for your visualization and click **Save**.
#
# 4. Your dashboard will be uploaded and accessible online.
#
# 💡 *If using **Tableau Desktop**, you can save your work locally as a `.twbx` file.*

# %% [markdown]
# ## Summary and Next Steps
# ### Key Takeaways
# - Tableau is a leading data visualization tool used for interactive analytics.
#
# - Tableau Public is a free version, while Tableau Desktop offers advanced features.
#
# - The Tableau interface includes the **Data Pane, Marks Card, Sheets, Dashboards, and Stories**.
#
# - Data sources can be connected easily, and Tableau automatically categorizes fields into <span style="color: blue;">**Dimensions (categorical fields)**</span> and <span style="color: green;">**Measures (numerical fields)**</span>.
#
# - Creating visualizations is intuitive, and different chart types serve different analytical purposes.
#
# - Tableau Public requires users to publish their work online.
#
# ### Next Lesson Preview
# The next lesson will focus on **Data Preparation and Cleaning in Tableau**, covering handling missing values, data transformations, and using **Joins and Blends** to combine multiple datasets.
