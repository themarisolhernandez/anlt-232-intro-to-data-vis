# %% [markdown]
# <p style="display: flex; align-items: center;">
#     <img src="https://seaborn.pydata.org/_images/logo-tall-lightbg.svg" alt="Seaborn Logo" width="50" style="margin-right: 10px;">
#     <span style="font-size: 32px; font-weight: bold;">📍 Seaborn’s Figure Styles & Themes</span>
# </p>

# %% [markdown]
# ## Introduction
# Effective data visualization isn't just about displaying data but also about making it **clear, aesthetically pleasing, and easy to interpret**. Seaborn builds on Matplotlib’s capabilities by offering **built-in themes and styles** that improve readability with minimal effort.
#
# In this lesson, we'll explore how Seaborn’s styling functions allow us to adjust **color themes, background styles, and contextual settings** to create well-designed plots.

# %% [markdown]
# ## Loading the Dataset
# To demonstrate Seaborn's figure styles and themes, we'll use the `tips` dataset, which contains information on restaurant bills, tips, and customer demographics.

# %%
import seaborn as sns
import matplotlib.pyplot as plt  # Import Matplotlib for further customization

# Sample data
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ## Setting Styles in Seaborn
# Seaborn provides **five built-in** themes to customize the appearance of plots:
#
# - `darkgrid` (default) – A grid with a dark background
#
# - `whitegrid` – A grid with a light background
#
# - `dark` – Dark background without gridlines
#
# - `white` – White background without gridlines
#
# - `ticks` – White background with ticks emphasized
#
# You can change the style using `sns.set_style()`:

# %%
# Apply a style
# See: https://seaborn.pydata.org/generated/seaborn.set_style.html
sns.set_style("whitegrid")

# Create a scatter plot of total_bill vs tip with custom style
sns.scatterplot(
    data=tips,  # Specifies the tips dataset as the data source
    x="total_bill",  # Uses the total bill column as the x-axis
    y="tip",  # Uses the tip column as the y-axis
)

# Adds a descriptive title
plt.title("Scatter Plot with 'whitegrid' Style")

# Shows the plot
plt.show()

# %% [markdown]
# 💡 **TODO:** Try replacing `"whitegrid"` with other styles to see how they affect the plot.
#
# ### **Sidebar —** You can check the current default style by running:

# %%
# See: https://seaborn.pydata.org/generated/seaborn.axes_style.html
print(sns.axes_style())
# Out:
# {'axes.facecolor': 'white', 'axes.edgecolor': '.8', 'axes.grid': True, 'axes.axisbelow': True, 'axes.labelcolor': '.15', 'figure.facecolor': 'white', 'grid.color': '.8', 'grid.linestyle': '-', 'text.color': '.15', 'xtick.color': '.15', 'ytick.color': '.15', 'xtick.direction': 'out', 'ytick.direction': 'out', 'lines.solid_capstyle': <CapStyle.round: 'round'>, 'patch.edgecolor': 'w', 'patch.force_edgecolor': True, 'image.cmap': 'rocket', 'font.family': ['sans-serif'], 'font.sans-serif': ['Arial', 'DejaVu Sans', 'Liberation Sans', 'Bitstream Vera Sans', 'sans-serif'], 'xtick.bottom': False, 'xtick.top': False, 'ytick.left': False, 'ytick.right': False, 'axes.spines.left': True, 'axes.spines.bottom': True, 'axes.spines.right': True, 'axes.spines.top': True}

# %% [markdown]
# As you can see, my global default style is set to `white`. To explicitly reset Seaborn to its default style, run:

# %%
# See: https://seaborn.pydata.org/generated/seaborn.set.html
sns.set()

# %% [markdown]
# Let's replot the same scatter plot now using Seaborn's default style, `darkgrid`.

# %%
# Replotting with Seaborn's deafault style
sns.scatterplot(
    data=tips,  # Specifies the tips dataset as the data source
    x="total_bill",  # Uses the total bill column as the x-axis
    y="tip",  # Uses the tip column as the y-axis
)

# Adds a descriptive title
plt.title("Scatter Plot with 'darkgrid' Style")

# Shows the plot
plt.show()

# %% [markdown]
# ## Customizing Figure Aesthetics
# Seaborn allows further control over individual plot elements using `sns.set_style()` with `rc` parameters. This provides fine-grained control over **grid visibility, axis colors, and more**.
#
# **Example:** Removing the top and right spines (borders of the plot):

# %%
# Apply a style including background and spine customization
sns.set_style("whitegrid", {"axes.spines.right": False, "axes.spines.top": False})

sns.scatterplot(
    data=tips,  # Specifies the tips dataset as the data source
    x="total_bill",  # Uses the total bill column as the x-axis
    y="tip",  # Uses the tip column as the y-axis
)

# Adds a descriptive title
plt.title("Scatter Plot with Customized Spines")

# Shows the plot
plt.show()

# %% [markdown]
# ## Changing Plot Context
# Seaborn includes a `set_context()` function that adjusts font size and element scaling based on the **intended use of the plot**. The available contexts are:
#
# - `paper` – For small plots in reports or articles
#
# - `notebook (default)` – For standard Jupyter Notebook visuals
#
# - `talk` – Enlarged text for presentations
#
# - `poster` – Even larger text for posters
#
# **Example:**

# %%
# TODO: Try replacing "talk" with other contexts to see how they affect the plot.
# See: https://seaborn.pydata.org/generated/seaborn.set_context.html
sns.set_context("talk")

sns.scatterplot(
    data=tips,  # Specifies the tips dataset as the data source
    x="total_bill",  # Uses the total bill column as the x-axis
    y="tip",  # Uses the tip column as the y-axis
)

# Adds a descriptive title
plt.title("Scatter Plot with 'talk' Context")

# Shows the plot
plt.show()

# %% [markdown]
# You can also fine-tune individual parameters:

# %%
# Adjust the font scale
sns.set_context("talk", font_scale=1.5)

sns.scatterplot(
    data=tips,  # Specifies the tips dataset as the data source
    x="total_bill",  # Uses the total bill column as the x-axis
    y="tip",  # Uses the tip column as the y-axis
)

# Adds a descriptive title
plt.title("Scatter Plot with 'talk' Context")

# Shows the plot
plt.show()

# %% [markdown]
# ## Using Seaborn’s Color Palettes
# Seaborn provides built-in color palettes that can be applied easily. To see available palettes:

# %%
# See: https://seaborn.pydata.org/generated/seaborn.color_palette.html
sns.color_palette()
# Out:
# [(0.2980392156862745, 0.4470588235294118, 0.6901960784313725),
#  (0.8666666666666667, 0.5176470588235295, 0.3215686274509804),
#  (0.3333333333333333, 0.6588235294117647, 0.40784313725490196),
#  (0.7686274509803922, 0.3058823529411765, 0.3215686274509804),
#  (0.5058823529411764, 0.4470588235294118, 0.7019607843137254),
#  (0.5764705882352941, 0.47058823529411764, 0.3764705882352941),
#  (0.8549019607843137, 0.5450980392156862, 0.7647058823529411),
#  (0.5490196078431373, 0.5490196078431373, 0.5490196078431373),
#  (0.8, 0.7254901960784313, 0.4549019607843137),
#  (0.39215686274509803, 0.7098039215686275, 0.803921568627451)]

# %% [markdown]
# To apply a color palette:

# %%
sns.set_context("notebook")

# Set the color palette
# See: https://seaborn.pydata.org/generated/seaborn.set_palette.html
sns.set_palette("pastel")

sns.scatterplot(
    data=tips,  # Specifies the tips dataset as the data source
    x="total_bill",  # Uses the total bill column as the x-axis
    y="tip",  # Uses the tip column as the y-axis
)

# Adds a descriptive title
plt.title("Scatter Plot with 'pastel' Palette")

# Shows the plot
plt.show()

# %% [markdown]
# Other common palettes:
#
# - `"deep"`
#
# - `"muted"`
#
# - `"bright"`
#
# - `"dark"`
#
# - `"colorblind"`
#
# You can also define a custom color palette:

# %%
# Set custom palette
custom_palette = ["#3498db", "#e74c3c", "#2ecc71"]
sns.set_palette(custom_palette)

sns.scatterplot(
    data=tips,  # Specifies the tips dataset as the data source
    x="total_bill",  # Uses the total bill column as the x-axis
    y="tip",  # Uses the tip column as the y-axis
)

# Adds a descriptive title
plt.title("Scatter Plot with Custom Palette")

# Shows the plot
plt.show()

# %% [markdown]
# ## Summary
# Seaborn makes it easy to adjust the aesthetics of visualizations with **predefined styles, themes, and color palettes**. By understanding and applying these features, we can create plots that are **not only informative but also visually appealing and tailored for different audiences**.
#
# In the next lesson, we will explore **Seaborn's categorical plots**, which help visualize relationships between categorical variables.

# %% [markdown]
# ## 2.1 Quick Challenge
# Now that you've learned how to modify Seaborn's **styles, contexts, and color palettes**, try this challenge. **Modify the visualization below by:**
#
# 1. Changing the figure style to `"darkgrid"`
#
# 2. Using the `"poster"` context
#
# 3. Applying the `"muted"` color palette

# %%
# Apply custom style, context, and palette
sns.set_style(None)  # TODO: Replace None with the style
sns.set_context(None)  # TODO: Replace None with the context
sns.set_palette(None)  # TODO: Replace None with the palette

# Create a scatter plot
sns.scatterplot(
    data=tips,  # Specifies the tips dataset as the data source
    x="total_bill",  # Uses the total bill column as the x-axis
    y="tip",  # Uses the tip column as the y-axis
)

# Adds a descriptive title
plt.title("Scatter Plot with Custom Aesthetics")

# Shows the plot
plt.show()

# %% [markdown]
# 💡 **Bonus**: Experiment with a custom color palette instead of a built-in one!
